# %%
from langgraph.graph import StateGraph,START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()  # take environment variables from .env file
# Out:
# True

# %%
model = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

# %%
class Blogstate(TypedDict):
    title: str
    outline: str
    content: str
    evaluation: int

# %%
def create_outline(state: Blogstate) -> Blogstate:
    # fetch title from state
    title = state["title"]
    # create prompt
    prompt = f"Create a detailed outline for a blog post titled '{title}'."
    # get outline from model
    outline = model.invoke(prompt).content
    # update state
    state["outline"] = outline
    return state

# %%
def create_blog(state: Blogstate) -> Blogstate:
    title = state["title"]
    # fetch outline from state
    outline = state["outline"]
    # create prompt;
    prompt = f"Write a detailed blog on the{title}based on the following outline:\n{outline}"
    # get content from model
    content = model.invoke(prompt).content
    # update state
    state["content"] = content
    return state

# %%
def evaluate_blog(state: Blogstate) -> Blogstate:
    content = state["content"]
    # create prompt
    prompt = f"Rate the following blog content on a scale of 1 to 10 for quality and coherence. Reply with only the number.\n\n{content}"
    # get evaluation from model
    evaluation = model.invoke(prompt).content
    # update state
    state["evaluation"] 
    return state

# %%
graph=StateGraph(Blogstate)

# %%
# Nodes
graph.add_node("create_outline",create_outline)
graph.add_node("create_blog",create_blog)
graph.add_node("evaluate_blog",evaluate_blog)

# %%
# add edges to the graph
graph.add_edge(START,"create_outline")
graph.add_edge("create_outline","create_blog")
graph.add_edge("create_blog","evaluate_blog")
graph.add_edge("evaluate_blog",END)

# %%
# compile the graph
workflow=graph.compile()

# %%
# execute the workflow
initial_state= {'title':'The Future of AI in Healthcare'}
final_state=workflow.invoke(initial_state)

# %%
print(final_state)
# Out:
# {'title': 'The Future of AI in Healthcare', 'outline': 'I. Introduction\n    A. Brief overview of AI in healthcare\n    B. Importance of AI in improving healthcare outcomes\n\nII. Current applications of AI in healthcare\n    A. Diagnostic imaging\n    B. Personalized medicine\n    C. Drug discovery\n    D. Virtual health assistants\n\nIII. Benefits of AI in healthcare\n    A. Improved accuracy and efficiency in diagnosis\n    B. Enhanced patient care and outcomes\n    C. Cost savings for healthcare providers\n    D. Increased accessibility to healthcare services\n\nIV. Challenges and limitations of AI in healthcare\n    A. Data privacy and security concerns\n    B. Lack of regulatory framework\n    C. Bias in AI algorithms\n    D. Integration with existing healthcare systems\n\nV. Future trends in AI in healthcare\n    A. Predictive analytics for early disease detection\n    B. Precision medicine for personalized treatment plans\n    C. Robotics and automation in surgery\n    D. Telemedicine and remote patient monitoring\n\nVI. Ethical considerations in AI in healthcare\n    A. Transparency and accountability in AI decision-making\n    B. Informed consent and patient autonomy\n    C. Addressing bias and discrimination in AI algorithms\n\nVII. Conclusion\n    A. Recap of the potential of AI in transforming healthcare\n    B. Call to action for stakeholders to collaborate and address challenges\n    C. Hope for a future where AI enhances healthcare delivery and improves patient outcomes.', 'content': 'AI in healthcare is revolutionizing the way medical professionals diagnose, treat, and care for patients. With the ability to analyze vast amounts of data and identify patterns that may not be apparent to the human eye, AI has the potential to significantly improve healthcare outcomes. In this blog, we will explore the current applications of AI in healthcare, the benefits and challenges associated with its implementation, future trends in the field, and ethical considerations that must be taken into account.\n\nCurrent applications of AI in healthcare include diagnostic imaging, personalized medicine, drug discovery, and virtual health assistants. Diagnostic imaging, in particular, has seen significant advancements with the use of AI algorithms to analyze medical images and detect abnormalities with high accuracy. Personalized medicine, on the other hand, utilizes AI to analyze genetic and clinical data to tailor treatment plans to individual patients. Drug discovery is also benefiting from AI technology, with algorithms being used to identify potential drug candidates and predict their efficacy. Virtual health assistants, such as chatbots and voice assistants, are being used to provide patients with information and support remotely.\n\nThe benefits of AI in healthcare are numerous. Improved accuracy and efficiency in diagnosis can lead to earlier detection of diseases and better treatment outcomes. Enhanced patient care and outcomes are also possible with AI technology, as it can help healthcare providers make more informed decisions about patient care. Cost savings for healthcare providers are another advantage of AI, as it can streamline processes and reduce the need for manual labor. Additionally, AI can increase accessibility to healthcare services for underserved populations by providing remote consultations and monitoring.\n\nDespite the many benefits of AI in healthcare, there are also challenges and limitations that must be addressed. Data privacy and security concerns are paramount, as the use of AI requires access to sensitive patient information. A lack of regulatory framework for AI in healthcare is also a challenge, as it can lead to uncertainty about the legal and ethical implications of using AI technology. Bias in AI algorithms is another issue that must be addressed, as it can lead to disparities in healthcare outcomes. Integration with existing healthcare systems is also a challenge, as AI technology must be se ...

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Brief overview of AI in healthcare
#     B. Importance of AI in improving healthcare outcomes
#
# II. Current applications of AI in healthcare
#     A. Diagnostic imaging
#     B. Personalized medicine
#     C. Drug discovery
#     D. Virtual health assistants
#
# III. Benefits of AI in healthcare
#     A. Improved accuracy and efficiency in diagnosis
#     B. Enhanced patient care and outcomes
#     C. Cost savings for healthcare providers
#     D. Increased accessibility to healthcare services
#
# IV. Challenges and limitations of AI in healthcare
#     A. Data privacy and security concerns
#     B. Lack of regulatory framework
#     C. Bias in AI algorithms
#     D. Integration with existing healthcare systems
#
# V. Future trends in AI in healthcare
#     A. Predictive analytics for early disease detection
#     B. Precision medicine for personalized treatment plans
#     C. Robotics and automation in surgery
#     D. Telemedicine and remote patient monitoring
#
# VI. Ethical considerations in AI in healthcare
#     A. Transparency and accountability in AI decision-making
#     B. Informed consent and patient autonomy
#     C. Addressing bias and discrimination in AI algorithms
#
# VII. Conclusion
#     A. Recap of the potential of AI in transforming healthcare
#     B. Call to action for stakeholders to collaborate and address challenges
#     C. Hope for a future where AI enhances healthcare delivery and improves patient outcomes.

# %%
print(final_state["content"])
# Out:
# AI in healthcare is revolutionizing the way medical professionals diagnose, treat, and care for patients. With the ability to analyze vast amounts of data and identify patterns that may not be apparent to the human eye, AI has the potential to significantly improve healthcare outcomes. In this blog, we will explore the current applications of AI in healthcare, the benefits and challenges associated with its implementation, future trends in the field, and ethical considerations that must be taken into account.
#
# Current applications of AI in healthcare include diagnostic imaging, personalized medicine, drug discovery, and virtual health assistants. Diagnostic imaging, in particular, has seen significant advancements with the use of AI algorithms to analyze medical images and detect abnormalities with high accuracy. Personalized medicine, on the other hand, utilizes AI to analyze genetic and clinical data to tailor treatment plans to individual patients. Drug discovery is also benefiting from AI technology, with algorithms being used to identify potential drug candidates and predict their efficacy. Virtual health assistants, such as chatbots and voice assistants, are being used to provide patients with information and support remotely.
#
# The benefits of AI in healthcare are numerous. Improved accuracy and efficiency in diagnosis can lead to earlier detection of diseases and better treatment outcomes. Enhanced patient care and outcomes are also possible with AI technology, as it can help healthcare providers make more informed decisions about patient care. Cost savings for healthcare providers are another advantage of AI, as it can streamline processes and reduce the need for manual labor. Additionally, AI can increase accessibility to healthcare services for underserved populations by providing remote consultations and monitoring.
#
# Despite the many benefits of AI in healthcare, there are also challenges and limitations that must be addressed. Data privacy and security concerns are paramount, as the use of AI requires access to sensitive patient information. A lack of regulatory framework for AI in healthcare is also a challenge, as it can lead to uncertainty about the legal and ethical implications of using AI technology. Bias in AI algorithms is another issue that must be addressed, as it can lead to disparities in healthcare outcomes. Integration with existing healthcare systems is also a challenge, as AI technology must be seamlessly integrated into workflows to be effective.
#
# Future trends in AI in healthcare include predictive analytics for early disease detection, precision medicine for personalized treatment plans, robotics and automation in surgery, and telemedicine and remote patient monitoring. Predictive analytics can help identify patients at risk for certain diseases before symptoms appear, allowing for early intervention. Precision medicine can help tailor treatment plans to individual patients based on their genetic and clinical data. Robotics and automation in surgery can improve surgical outcomes and reduce the risk of human error. Telemedicine and remote patient monitoring can increase access to healthcare services for patients in remote areas.
#
# Ethical considerations in AI in healthcare are crucial to ensure that the technology is used responsibly and ethically. Transparency and accountability in AI decision-making are essential to build trust with patients and healthcare providers. Informed consent and patient autonomy must also be respected when using AI technology in healthcare. Addressing bias and discrimination in AI algorithms is important to ensure that all patients receive fair and equitable treatment.
#
# In conclusion, the future of AI in healthcare is bright, with the potential to transform the way healthcare is delivered and improve patient outcomes. However, it is important for stakeholders to collaborate and address the challenges associated with implementing AI technology in healthcare. By working together, we can create a future where AI enhances healthcare delivery and improves patient outcomes for all.

# %%
print(final_state["evaluation"])
# Out:
# 8
