# %%
from langgraph.graph import StateGraph,START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()  # take environment variables from .env file
# Out:
# True

# %%
model = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

# %%
class Blogstate(TypedDict):
    title: str
    outline: str
    content: str
    evaluation: int

# %%
def create_outline(state: Blogstate) -> Blogstate:
    # fetch title from state
    title = state["title"]
    # create prompt
    prompt = f"Create a detailed outline for a blog post titled '{title}'."
    # get outline from model
    outline = model.invoke(prompt).content
    # update state
    state["outline"] = outline
    return state

# %%
def create_blog(state: Blogstate) -> Blogstate:
    title = state["title"]
    # fetch outline from state
    outline = state["outline"]
    # create prompt;
    prompt = f"Write a detailed blog on the{title}based on the following outline:\n{outline}"
    # get content from model
    content = model.invoke(prompt).content
    # update state
    state["content"] = content
    return state

# %%
def evaluate_blog(state: Blogstate) -> Blogstate:
    content = state["content"]
    # create prompt
    prompt = prompt = f"Rate the following blog content on a scale of 1 to 10 for quality and coherence. Reply with only the number.\n\n{content}"
    # get evaluation from model
    evaluation = int(model.invoke(prompt).content)
    # update state
    state["evaluation"] = evaluation
    return state

# %%
graph=StateGraph(Blogstate)

# %%
# Nodes
graph.add_node("create_outline",create_outline)
graph.add_node("create_blog",create_blog)
graph.add_node("evaluate_blog",evaluate_blog)

# %%
# add edges to the graph
graph.add_edge(START,"create_outline")
graph.add_edge("create_outline","create_blog")
graph.add_edge("create_blog","evaluate_blog")
graph.add_edge("evaluate_blog",END)
# Out:
# Adding an edge to a graph that has already been compiled. This will not be reflected in the compiled graph.
# Adding an edge to a graph that has already been compiled. This will not be reflected in the compiled graph.
# Adding an edge to a graph that has already been compiled. This will not be reflected in the compiled graph.
# Adding an edge to a graph that has already been compiled. This will not be reflected in the compiled graph.

# %%
# compile the graph
workflow=graph.compile()

# %%
# execute the workflow
initial_state= {'title':'The Future of AI in Healthcare'}
final_state=workflow.invoke(initial_state)

# %%
pr

# %%
print(final_state)
# Out:
# {'title': 'The Future of AI in Healthcare', 'outline': 'I. Introduction\n    A. Brief overview of AI in healthcare\n    B. Importance of AI in improving healthcare outcomes\n\nII. Current applications of AI in healthcare\n    A. Diagnostic imaging\n    B. Personalized medicine\n    C. Drug discovery\n    D. Virtual health assistants\n\nIII. Benefits of AI in healthcare\n    A. Improved accuracy and efficiency in diagnosis\n    B. Enhanced patient care and outcomes\n    C. Cost savings for healthcare providers\n    D. Increased accessibility to healthcare services\n\nIV. Challenges and limitations of AI in healthcare\n    A. Data privacy and security concerns\n    B. Lack of regulatory framework\n    C. Bias in AI algorithms\n    D. Integration with existing healthcare systems\n\nV. Future trends in AI in healthcare\n    A. Predictive analytics for early disease detection\n    B. Precision medicine for personalized treatment plans\n    C. Robotics and automation in surgery\n    D. Telemedicine and remote patient monitoring\n\nVI. Ethical considerations in AI in healthcare\n    A. Patient consent and transparency\n    B. Accountability and liability\n    C. Equity and access to AI healthcare technologies\n\nVII. Conclusion\n    A. Recap of the potential of AI in transforming healthcare\n    B. Call to action for stakeholders to collaborate and address challenges\n    C. Excitement for the future of AI in healthcare.', 'content': "AI in healthcare is revolutionizing the way medical professionals diagnose, treat, and care for patients. With the ability to analyze vast amounts of data and identify patterns that humans may overlook, AI has the potential to significantly improve healthcare outcomes. In this blog, we will explore the current applications of AI in healthcare, the benefits and challenges it presents, future trends, and ethical considerations.\n\nCurrent applications of AI in healthcare include diagnostic imaging, personalized medicine, drug discovery, and virtual health assistants. Diagnostic imaging, such as MRI and CT scans, can be analyzed by AI algorithms to detect abnormalities and assist radiologists in making more accurate diagnoses. Personalized medicine uses AI to analyze genetic and clinical data to tailor treatment plans to individual patients. Drug discovery is accelerated by AI algorithms that can predict how molecules will interact with biological targets, leading to the development of new drugs. Virtual health assistants, such as chatbots and voice assistants, provide patients with information and support, improving access to healthcare services.\n\nThe benefits of AI in healthcare are numerous. Improved accuracy and efficiency in diagnosis can lead to earlier detection of diseases and better treatment outcomes. Enhanced patient care and outcomes result from personalized treatment plans and remote monitoring enabled by AI technologies. Cost savings for healthcare providers are achieved through increased efficiency and reduced errors. Increased accessibility to healthcare services is possible through telemedicine and virtual health assistants, especially in underserved areas.\n\nHowever, there are challenges and limitations to consider when implementing AI in healthcare. Data privacy and security concerns arise when sensitive patient information is stored and analyzed by AI systems. The lack of a regulatory framework for AI in healthcare raises questions about accountability and liability in case of errors or malpractice. Bias in AI algorithms can lead to disparities in healthcare outcomes for certain populations. Integration with existing healthcare systems can be complex and require significant resources.\n\nFuture trends in AI in healthcare include predictive analytics for early disease detection, precision medicine for personalized treatment plans, robotics and automation in surgery, and telemedicine and remote patient monitoring. These advancements have the potential to further improve healthcare outc ...

# %%
print(final_state['outline'])
# Out:
# I. Introduction
#     A. Brief overview of AI in healthcare
#     B. Importance of AI in improving healthcare outcomes
#
# II. Current applications of AI in healthcare
#     A. Diagnostic imaging
#     B. Personalized medicine
#     C. Drug discovery
#     D. Virtual health assistants
#
# III. Benefits of AI in healthcare
#     A. Improved accuracy and efficiency in diagnosis
#     B. Enhanced patient care and outcomes
#     C. Cost savings for healthcare providers
#     D. Increased accessibility to healthcare services
#
# IV. Challenges and limitations of AI in healthcare
#     A. Data privacy and security concerns
#     B. Lack of regulatory framework
#     C. Bias in AI algorithms
#     D. Integration with existing healthcare systems
#
# V. Future trends in AI in healthcare
#     A. Predictive analytics for early disease detection
#     B. Precision medicine for personalized treatment plans
#     C. Robotics and automation in surgery
#     D. Telemedicine and remote patient monitoring
#
# VI. Ethical considerations in AI in healthcare
#     A. Patient consent and transparency
#     B. Accountability and liability
#     C. Equity and access to AI healthcare technologies
#
# VII. Conclusion
#     A. Recap of the potential of AI in transforming healthcare
#     B. Call to action for stakeholders to collaborate and address challenges
#     C. Excitement for the future of AI in healthcare.

# %%
print(final_state["content"])
# Out:
# AI in healthcare is revolutionizing the way medical professionals diagnose, treat, and care for patients. With the ability to analyze vast amounts of data and identify patterns that humans may overlook, AI has the potential to significantly improve healthcare outcomes. In this blog, we will explore the current applications of AI in healthcare, the benefits and challenges it presents, future trends, and ethical considerations.
#
# Current applications of AI in healthcare include diagnostic imaging, personalized medicine, drug discovery, and virtual health assistants. Diagnostic imaging, such as MRI and CT scans, can be analyzed by AI algorithms to detect abnormalities and assist radiologists in making more accurate diagnoses. Personalized medicine uses AI to analyze genetic and clinical data to tailor treatment plans to individual patients. Drug discovery is accelerated by AI algorithms that can predict how molecules will interact with biological targets, leading to the development of new drugs. Virtual health assistants, such as chatbots and voice assistants, provide patients with information and support, improving access to healthcare services.
#
# The benefits of AI in healthcare are numerous. Improved accuracy and efficiency in diagnosis can lead to earlier detection of diseases and better treatment outcomes. Enhanced patient care and outcomes result from personalized treatment plans and remote monitoring enabled by AI technologies. Cost savings for healthcare providers are achieved through increased efficiency and reduced errors. Increased accessibility to healthcare services is possible through telemedicine and virtual health assistants, especially in underserved areas.
#
# However, there are challenges and limitations to consider when implementing AI in healthcare. Data privacy and security concerns arise when sensitive patient information is stored and analyzed by AI systems. The lack of a regulatory framework for AI in healthcare raises questions about accountability and liability in case of errors or malpractice. Bias in AI algorithms can lead to disparities in healthcare outcomes for certain populations. Integration with existing healthcare systems can be complex and require significant resources.
#
# Future trends in AI in healthcare include predictive analytics for early disease detection, precision medicine for personalized treatment plans, robotics and automation in surgery, and telemedicine and remote patient monitoring. These advancements have the potential to further improve healthcare outcomes and patient experiences.
#
# Ethical considerations in AI in healthcare are crucial to ensure that patients' rights and well-being are protected. Patient consent and transparency are essential when using AI technologies to make healthcare decisions. Accountability and liability must be clearly defined to address potential errors or malpractice. Equity and access to AI healthcare technologies must be prioritized to ensure that all patients benefit from these advancements.
#
# In conclusion, the future of AI in healthcare is promising and has the potential to transform the way healthcare is delivered. Stakeholders in the healthcare industry must collaborate to address challenges and ensure that AI technologies are implemented ethically and responsibly. The excitement for the future of AI in healthcare lies in its ability to improve patient outcomes, increase efficiency, and enhance access to healthcare services for all.
